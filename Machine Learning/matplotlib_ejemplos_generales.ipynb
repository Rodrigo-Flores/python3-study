# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(2,9,10)
x
# Out:
# array([2.        , 2.77777778, 3.55555556, 4.33333333, 5.11111111,
#        5.88888889, 6.66666667, 7.44444444, 8.22222222, 9.        ])

# %%
y = x**2
y
# Out:
# array([ 4.        ,  7.71604938, 12.64197531, 18.77777778, 26.12345679,
#        34.67901235, 44.44444444, 55.41975309, 67.60493827, 81.        ])

# %%
plt.plot(x,y, "red") # "red" = "r"
plt.title("Este es mi gráfico")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.show()

# %%
plt.subplot(1,2,1) # (filas, columnas)
plt.plot(x,y,"g")

plt.subplot(1,2,2)
plt.plot(y,x,"b")

# %%
plt.subplot(2,1,1)
plt.plot(x,y,"g")

plt.subplot(2,1,2)
plt.plot(y,x,"b")

# %% [markdown]
# Programación orientada a objetos

# %%
figura = plt.figure()
grafico = figura.add_axes([0.1,0.1,0.9,0.9]) # (separacion arrriba, separacion abajo, ancho, alto,)
grafico.plot(x,y,"g")

# %%
figura = plt.figure()
grafico1 = figura.add_axes([0.1,0.1,0.9,0.9])
grafico1.plot(x,y,"r")

grafico2 = figura.add_axes([0.2,0.5,0.3,0.3])
grafico2.plot(x,y,"b")
